# %%
import pandas as pd

# Replace 'yellow_tripdata_2023-01.parquet' with the actual path to your file
df = pd.read_parquet('yellow_tripdata_2023-01.parquet')

# You can now display the first few rows of the DataFrame to verify it loaded correctly
display(df.head())
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1         2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2         2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3         1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4         2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.97         1.0                  N           161           141
# 1           1.10         1.0                  N            43           237
# 2           2.51         1.0                  N            48           238
# 3           1.90         1.0                  N           138             7
# 4           1.43         1.0                  N           107            79
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
import pandas as pd
import numpy as np

# Read the parquet file
try:
    df = pd.read_parquet('yellow_tripdata_2023-01.parquet')
    
    # Get number of columns
    num_columns = len(df.columns)
    print(f"Number of columns: {num_columns}")
    print(f"Column names: {list(df.columns)}")
    
    # Basic information about the dataframe
    print("\nDataFrame Info:")
    print(f"Shape: {df.shape}")
    print(f"Data types:\n{df.dtypes}")
    
    # Descriptive statistics
    print("\nDescriptive Statistics:")
    print(df.describe())
    
    # Display head (first 5 rows)
    print("\nHead (First 5 rows):")
    print(df.head())
    
    # Display tail (last 5 rows)
    print("\nTail (Last 5 rows):")
    print(df.tail())
    
except FileNotFoundError:
    print("Error: The file 'yellow_tripdata_2023-01.parquet' was not found.")
    print("Please make sure the file exists in the current directory.")
except Exception as e:
    print(f"An error occurred: {str(e)}")
    print("Suggestions:")
    print("1. Check if you have the required packages installed (pandas, pyarrow)")
    print("2. Verify the file path is correct")
    print("3. Ensure the file is not corrupted")
# Out:
# Number of columns: 19
# Column names: ['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime', 'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag', 'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount', 'congestion_surcharge', 'airport_fee']
#
# DataFrame Info:
# Shape: (3066766, 19)
# Data types:
# VendorID                          int64
# tpep_pickup_datetime     datetime64[us]
# tpep_dropoff_datetime    datetime64[us]
# passenger_count                 float64
# trip_distance                   float64
# RatecodeID                      float64
# store_and_fwd_flag               object
# PULocationID                      int64
# DOLocationID                      int64
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# ...

# %%
import pandas as pd
import numpy as np

# Read the parquet file
try:
    df = pd.read_parquet('yellow_tripdata_2023-01.parquet')
    
    # Get number of columns
    num_columns = len(df.columns)
    print(f"Number of columns: {num_columns}")
    print(f"Column names: {list(df.columns)}")
    
    # Basic information about the dataframe
    print("\nDataFrame Info:")
    print(f"Shape: {df.shape}")
    print(f"Data types:\n{df.dtypes}")
    
    # Descriptive statistics
    print("\nDescriptive Statistics:")
    print(df.describe())
    
    # Display head (first 5 rows)
    print("\nHead (First 5 rows):")
    print(df.head())
    
    # Display tail (last 5 rows)
    print("\nTail (Last 5 rows):")
    print(df.tail())
    
except FileNotFoundError:
    print("Error: The file 'yellow_tripdata_2023-01.parquet' was not found.")
    print("Please make sure the file exists in the current directory.")
except Exception as e:
    print(f"An error occurred: {str(e)}")
    print("Suggestions:")
    print("1. Check if you have the required packages installed (pandas, pyarrow)")
    print("2. Verify the file path is correct")
    print("3. Ensure the file is not corrupted")
# Out:
# Number of columns: 19
# Column names: ['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime', 'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag', 'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount', 'congestion_surcharge', 'airport_fee']
#
# DataFrame Info:
# Shape: (3066766, 19)
# Data types:
# VendorID                          int64
# tpep_pickup_datetime     datetime64[us]
# tpep_dropoff_datetime    datetime64[us]
# passenger_count                 float64
# trip_distance                   float64
# RatecodeID                      float64
# store_and_fwd_flag               object
# PULocationID                      int64
# DOLocationID                      int64
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# ...

# %%
import pandas as pd
import numpy as np

# Read the parquet file
try:
    df = pd.read_parquet('yellow_tripdata_2023-01.parquet')
    
    # Compute trip duration in minutes
    df['trip_duration_minutes'] = (df['tpep_dropoff_datetime'] - df['tpep_pickup_datetime']).dt.total_seconds() / 60
    
    # Check for any negative durations (data quality issue)
    negative_durations = df[df['trip_duration_minutes'] < 0]
    num_negative = len(negative_durations)
    
    if num_negative > 0:
        print(f"Found {num_negative} trips with negative duration. These might be data errors.")
        print("Sample of negative durations:")
        print(negative_durations[['tpep_pickup_datetime', 'tpep_dropoff_datetime', 'trip_duration_minutes']].head())
        
        # For analysis purposes, we'll filter out negative durations
        df = df[df['trip_duration_minutes'] >= 0]
        print(f"Continuing analysis with {len(df)} valid records\n")
    
    # Basic statistics of trip duration
    print("Trip Duration Statistics (in minutes):")
    print(f"Mean: {df['trip_duration_minutes'].mean():.2f}")
    print(f"Median: {df['trip_duration_minutes'].median():.2f}")
    print(f"Standard Deviation: {df['trip_duration_minutes'].std():.2f}")
    print(f"Min: {df['trip_duration_minutes'].min():.2f}")
    print(f"Max: {df['trip_duration_minutes'].max():.2f}")
    
    # Distribution information
    print("\nPercentiles:")
    percentiles = [10, 25, 50, 75, 90, 95, 99]
    for p in percentiles:
        print(f"{p}th percentile: {df['trip_duration_minutes'].quantile(p/100):.2f}")
    
    # Count trips by duration ranges
    print("\nTrip counts by duration:")
    duration_bins = [0, 5, 10, 15, 30, 60, 120, df['trip_duration_minutes'].max()]
    trip_counts = pd.cut(df['trip_duration_minutes'], bins=duration_bins).value_counts().sort_index()
    print(trip_counts)
    
except FileNotFoundError:
    print("Error: The file 'yellow_tripdata_2023-01.parquet' was not found.")
except Exception as e:
    print(f"An error occurred: {str(e)}")
# Out:
# Found 3 trips with negative duration. These might be data errors.
# Sample of negative durations:
#         tpep_pickup_datetime tpep_dropoff_datetime  trip_duration_minutes
# 1839180  2023-01-20 13:35:00   2023-01-20 13:05:48             -29.200000
# 2124414  2023-01-23 10:43:58   2023-01-23 10:29:26             -14.533333
# 2218504  2023-01-24 11:00:00   2023-01-24 10:40:48             -19.200000
# Continuing analysis with 3066763 valid records
#
# Trip Duration Statistics (in minutes):
# Mean: 15.67
# Median: 11.52
# Standard Deviation: 42.59
# Min: 0.00
# Max: 10029.18
#
# Percentiles:
# 10th percentile: 4.48
# 25th percentile: 7.12
# 50th percentile: 11.52
# 75th percentile: 18.30
# 90th percentile: 27.95
# 95th percentile: 36.47
# 99th percentile: 57.25
#
# Trip counts by duration:
# trip_duration_minutes
# (0.0, 5.0]            387683
# (5.0, 10.0]           900479
# (10.0, 15.0]          701327
# (15.0, 30.0]          819299
# (30.0, 60.0]          232599
# ...

# %%
import pandas as pd
import numpy as np

# Read the parquet file
try:
    # Load the data
    df = pd.read_parquet('yellow_tripdata_2023-01.parquet')
    
    # Calculate the total number of records in the original dataset
    total_records = len(df)
    print(f"Total records in original dataset: {total_records:,}")
    
    # Compute trip duration in minutes
    df['trip_duration_minutes'] = (df['tpep_dropoff_datetime'] - df['tpep_pickup_datetime']).dt.total_seconds() / 60
    
    # Analyze the distribution of trip durations before filtering
    print("\nTrip Duration Distribution (before filtering):")
    print(f"Min: {df['trip_duration_minutes'].min():.2f} minutes")
    print(f"Max: {df['trip_duration_minutes'].max():.2f} minutes")
    print(f"Mean: {df['trip_duration_minutes'].mean():.2f} minutes")
    print(f"Median: {df['trip_duration_minutes'].median():.2f} minutes")
    print(f"Standard Deviation: {df['trip_duration_minutes'].std():.2f} minutes")
    
    # Show percentiles to understand the distribution
    percentiles = [1, 5, 10, 25, 50, 75, 90, 95, 99]
    print("\nPercentiles before filtering:")
    for p in percentiles:
        print(f"{p}th percentile: {df['trip_duration_minutes'].quantile(p/100):.2f} minutes")
    
    # Count records outside our target range (1-60 minutes)
    less_than_1min = (df['trip_duration_minutes'] < 1).sum()
    more_than_60min = (df['trip_duration_minutes'] > 60).sum()
    
    print(f"\nRecords with duration < 1 minute: {less_than_1min:,} ({less_than_1min/total_records:.2%})")
    print(f"Records with duration > 60 minutes: {more_than_60min:,} ({more_than_60min/total_records:.2%})")
    
    # Filter to keep only records with duration between 1 and 60 minutes (inclusive)
    filtered_df = df[(df['trip_duration_minutes'] >= 1) & (df['trip_duration_minutes'] <= 60)]
    
    # Calculate the number of records after filtering
    filtered_records = len(filtered_df)
    
    # Calculate the fraction of records remaining
    fraction_remaining = filtered_records / total_records
    
    print(f"\nRecords after filtering (1-60 minutes): {filtered_records:,}")
    print(f"Fraction of records remaining: {fraction_remaining:.6f} ({fraction_remaining:.2%})")
    
    # Show distribution statistics after filtering
    print("\nTrip Duration Distribution (after filtering):")
    print(f"Min: {filtered_df['trip_duration_minutes'].min():.2f} minutes")
    print(f"Max: {filtered_df['trip_duration_minutes'].max():.2f} minutes")
    print(f"Mean: {filtered_df['trip_duration_minutes'].mean():.2f} minutes")
    print(f"Median: {filtered_df['trip_duration_minutes'].median():.2f} minutes")
    print(f"Standard Deviation: {filtered_df['trip_duration_minutes'].std():.2f} minutes")
    
except FileNotFoundError:
    print("Error: The file 'yellow_tripdata_2023-01.parquet' was not found.")
except Exception as e:
    print(f"An error occurred: {str(e)}")
# Out:
# Total records in original dataset: 3,066,766
#
# Trip Duration Distribution (before filtering):
# Min: -29.20 minutes
# Max: 10029.18 minutes
# Mean: 15.67 minutes
# Median: 11.52 minutes
# Standard Deviation: 42.59 minutes
#
# Percentiles before filtering:
# 1th percentile: 0.78 minutes
# 5th percentile: 3.30 minutes
# 10th percentile: 4.48 minutes
# 25th percentile: 7.12 minutes
# 50th percentile: 11.52 minutes
# 75th percentile: 18.30 minutes
# 90th percentile: 27.94 minutes
# 95th percentile: 36.47 minutes
# 99th percentile: 57.25 minutes
#
# Records with duration < 1 minute: 33,335 (1.09%)
# Records with duration > 60 minutes: 24,258 (0.79%)
#
# Records after filtering (1-60 minutes): 3,009,173
# Fraction of records remaining: 0.981220 (98.12%)
#
# Trip Duration Distribution (after filtering):
# Min: 1.00 minutes
# Max: 60.00 minutes
# Mean: 14.20 minutes
# Median: 11.55 minutes
# Standard Deviation: 9.94 minutes

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction import DictVectorizer

try:
    # Load the parquet file
    df = pd.read_parquet('yellow_tripdata_2023-01.parquet')
    
    # Calculate trip duration in minutes
    df['trip_duration_minutes'] = (df['tpep_dropoff_datetime'] - df['tpep_pickup_datetime']).dt.total_seconds() / 60
    
    # Filter to keep only records with duration between 1 and 60 minutes (inclusive)
    filtered_df = df[(df['trip_duration_minutes'] >= 1) & (df['trip_duration_minutes'] <= 60)]
    
    print(f"Records after filtering (1-60 minutes): {len(filtered_df):,}")
    
    # Check the column names to identify pickup and dropoff location IDs
    print("\nAvailable columns:")
    print(filtered_df.columns.tolist())
    
    # Assuming the location IDs are 'PULocationID' and 'DOLocationID'
    # Extract only the needed columns
    features_df = filtered_df[['PULocationID', 'DOLocationID']]
    
    # Check for missing values
    missing_values = features_df.isnull().sum()
    print(f"\nMissing values:\n{missing_values}")
    
    # Drop rows with missing values if any
    if missing_values.sum() > 0:
        features_df = features_df.dropna()
        print(f"Dropped rows with missing values. Remaining rows: {len(features_df):,}")
    
    # Convert location IDs to strings to ensure proper one-hot encoding
    features_df['PULocationID'] = 'pickup_' + features_df['PULocationID'].astype(str)
    features_df['DOLocationID'] = 'dropoff_' + features_df['DOLocationID'].astype(str)
    
    # Convert DataFrame to list of dictionaries
    dict_records = features_df.to_dict(orient='records')
    
    print(f"\nSample of dictionary records (first 3):")
    for i, record in enumerate(dict_records[:3]):
        print(f"{i+1}: {record}")
    
    # Initialize and fit the DictVectorizer
    dv = DictVectorizer(sparse=False)
    X = dv.fit_transform(dict_records)
    
    # Get the feature names
    feature_names = dv.get_feature_names_out()
    
    # Calculate dimensionality (number of columns)
    dimensionality = X.shape[1]
    
    print(f"\nDimensionality of the feature matrix: {dimensionality}")
    print(f"Shape of the feature matrix: {X.shape}")
    
    # Count unique pickup and dropoff locations
    unique_pickups = len([f for f in feature_names if f.startswith('pickup_')])
    unique_dropoffs = len([f for f in feature_names if f.startswith('dropoff_')])
    
    print(f"\nNumber of unique pickup locations: {unique_pickups}")
    print(f"Number of unique dropoff locations: {unique_dropoffs}")
    print(f"Total unique locations: {len(set([int(f.split('_')[1]) for f in feature_names]))}")
    
    # Show a sample of the one-hot encoded matrix
    print("\nSample of the feature matrix (first 3 rows, first 10 columns):")
    print(X[:3, :10])
    
except FileNotFoundError:
    print("Error: The file 'yellow_tripdata_2023-01.parquet' was not found.")
except Exception as e:
    print(f"An error occurred: {str(e)}")
# Out:
# Records after filtering (1-60 minutes): 3,009,173
#
# Available columns:
# ['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime', 'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag', 'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra', 'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount', 'congestion_surcharge', 'airport_fee', 'trip_duration_minutes']
#
# Missing values:
# PULocationID    0
# DOLocationID    0
# dtype: int64
# C:\Users\shaik\AppData\Local\Temp\ipykernel_12976\703806212.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features_df['PULocationID'] = 'pickup_' + features_df['PULocationID'].astype(str)
# ...

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Create sample data since we don't have the actual DataFrame
# Replace this with your actual data loading code
import pandas as pd
np.random.seed(42)
df = pd.DataFrame({
    'feature1': np.random.rand(100),
    'feature2': np.random.rand(100),
    # Rename 'duration' to match your actual target column name
    # or create the column if it doesn't exist
    'duration': np.random.rand(100) * 10  # Sample target variable
})

# Extract features
X = df[['feature1', 'feature2']]  # Use your actual feature columns

# Extract the target variable with the correct column name
# Make sure this column exists in your DataFrame
y = df['duration']  # Use the correct column name from your DataFrame

# Create a linear regression model
model = LinearRegression()

# Train the model
model.fit(X, y)

# Make predictions on the training data
y_pred = model.predict(X)

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y, y_pred))

print(f"RMSE on training data: {rmse:.4f}")
# Out:
# RMSE on training data: 2.8854
